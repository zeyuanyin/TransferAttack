# %%
import pandas as pd
import os
from tqdm import tqdm
import numpy as np

# %%
# load pd in /home/zeyuan.yin/My-Adv/imagenet-check/cls_results_all_true_val.csv

df = pd.read_csv('/home/zeyuan.yin/My-Adv/imagenet-check/cls_results_all_true_val.csv', header=0)
print(df.head())
# Out:
#                            name  label
# 0  ILSVRC2012_val_00006697.JPEG      0
# 1  ILSVRC2012_val_00007197.JPEG      0
# 2  ILSVRC2012_val_00009111.JPEG      0
# 3  ILSVRC2012_val_00009191.JPEG      0
# 4  ILSVRC2012_val_00009346.JPEG      0

# %%
dir_path = '/home/zeyuan.yin/My-Adv/data/images/'
os.makedirs(dir_path, exist_ok=True)

# for name in add_filename:
#     os.system('cp /l/users/zeyuan.yin/raw_val/' + name + ' '+ dir_path + name)

# check the number of images in data/
print(len(os.listdir(dir_path)))
# Out:
# 1000

# %%
## generate the csv file

# gen labels.csv
# filename,label
# ILSVRC2012_val_00013716.JPEG,0
# ILSVRC2012_val_00020785.JPEG,1

# load pd in /home/zeyuan.yin/My-Adv/imagenet-check/cls_results_val.csv

df = pd.read_csv('/home/zeyuan.yin/My-Adv/imagenet-check/cls_results_val.csv', header=0)
# print(df.head())

# load all filename under /home/zeyuan.yin/My-Adv/data/images
all_filename = os.listdir(dir_path)
print(all_filename)

if 'ILSVRC2012_val_00002836.JPEG' in all_filename:
    print('yes')
else:
    print('no')

# extract df for only name in add_filename
df = df[df['name'].isin(all_filename)]
print(len(df))
# print(df.head(5))

# only save the name and label in df
df = df[['name', 'label']]

df = df.rename(columns={'name': 'filename'})
print(df.head(5))

# df.to_csv('/home/zeyuan.yin/My-Adv/data/labels_no_target.csv', index=False)
# Out:
# ['ILSVRC2012_val_00000341.JPEG', 'ILSVRC2012_val_00035146.JPEG', 'ILSVRC2012_val_00012098.JPEG', 'ILSVRC2012_val_00016396.JPEG', 'ILSVRC2012_val_00007101.JPEG', 'ILSVRC2012_val_00000160.JPEG', 'ILSVRC2012_val_00002131.JPEG', 'ILSVRC2012_val_00001215.JPEG', 'ILSVRC2012_val_00026067.JPEG', 'ILSVRC2012_val_00000287.JPEG', 'ILSVRC2012_val_00000871.JPEG', 'ILSVRC2012_val_00031279.JPEG', 'ILSVRC2012_val_00012305.JPEG', 'ILSVRC2012_val_00045814.JPEG', 'ILSVRC2012_val_00046707.JPEG', 'ILSVRC2012_val_00030698.JPEG', 'ILSVRC2012_val_00001286.JPEG', 'ILSVRC2012_val_00026277.JPEG', 'ILSVRC2012_val_00011673.JPEG', 'ILSVRC2012_val_00036395.JPEG', 'ILSVRC2012_val_00000748.JPEG', 'ILSVRC2012_val_00032854.JPEG', 'ILSVRC2012_val_00007152.JPEG', 'ILSVRC2012_val_00014953.JPEG', 'ILSVRC2012_val_00017488.JPEG', 'ILSVRC2012_val_00016146.JPEG', 'ILSVRC2012_val_00000858.JPEG', 'ILSVRC2012_val_00020416.JPEG', 'ILSVRC2012_val_00015043.JPEG', 'ILSVRC2012_val_00001868.JPEG', 'ILSVRC2012_val_00028810.JPEG', 'ILSVRC2012_val_00016597.JPEG', 'ILSVRC2012_val_00009179.JPEG', 'ILSVRC2012_val_00007373.JPEG', 'ILSVRC2012_val_00047194.JPEG', 'ILSVRC2012_val_00048268.JPEG', 'ILSVRC2012_val_00006917.JPEG', 'ILSVRC2012_val_00027446.JPEG', 'ILSVRC2012_val_00036901.JPEG', 'ILSVRC2012_val_00004381.JPEG', 'ILSVRC2012_val_00003128.JPEG', 'ILSVRC2012_val_00040524.JPE
# no
# 1000
#                          filename  label
# 14   ILSVRC2012_val_00013716.JPEG      0
# 74   ILSVRC2012_val_00020785.JPEG      1
# 138  ILSVRC2012_val_00037998.JPEG      2
# 177  ILSVRC2012_val_00029568.JPEG      3
# 233  ILSVRC2012_val_00031424.JPEG      4

# %%
## generate random target label (int)

df = pd.read_csv('/home/zeyuan.yin/My-Adv/data/labels_no_target.csv', header=0)

print(df.dtypes)
for label in df['label']:
    targeted_label = np.random.randint(0, 1000)
    assert targeted_label != label, 'retry'
    df.loc[df['label'] == label, 'targeted_label'] = str(int(targeted_label))


print(df.head(5))

df.to_csv('/home/zeyuan.yin/My-Adv/new_data/labels.csv', index=False)
# Out:
# filename    object
# label        int64
# dtype: object
#                        filename  label targeted_label
# 0  ILSVRC2012_val_00013716.JPEG      0            631
# 1  ILSVRC2012_val_00020785.JPEG      1            250
# 2  ILSVRC2012_val_00037998.JPEG      2            800
# 3  ILSVRC2012_val_00029568.JPEG      3            263
# 4  ILSVRC2012_val_00031424.JPEG      4            226

# %% [markdown]
# ## doule check

# %%
# load list at /home/zeyuan.yin/My-Adv/TransferAttack_sync/not_correct_list_label.pkl

import os
import pickle
import numpy as np
import pandas as pd


not_correct_list_label = pickle.load(open('/home/zeyuan.yin/My-Adv/TransferAttack_sync/not_correct_list_label.pkl', 'rb'))
not_correct_list_name = pickle.load(open('/home/zeyuan.yin/My-Adv/TransferAttack_sync/not_correct_list_name.pkl', 'rb'))

print(len(not_correct_list_label))
print(len(not_correct_list_name))

print(not_correct_list_label)
print(not_correct_list_name)

# 1st
# [(58,), (269,), (595,), (79,), (369,), (596,), (837,), (248,), (664,), (572,)]
# [('ILSVRC2012_val_00002836.JPEG',), ('ILSVRC2012_val_00000912.JPEG',), ('ILSVRC2012_val_00001840.JPEG',), ('ILSVRC2012_val_00003981.JPEG',), ('ILSVRC2012_val_00002857.JPEG',), ('ILSVRC2012_val_00002588.JPEG',), ('ILSVRC2012_val_00005437.JPEG',), ('ILSVRC2012_val_00002066.JPEG',), ('ILSVRC2012_val_00004758.JPEG',), ('ILSVRC2012_val_00004591.JPEG',)]

# 2nd
# [(664,)]
# [('ILSVRC2012_val_00017128.JPEG',)]

# 3rd
# [(664,)]
# [('ILSVRC2012_val_00026247.JPEG',)]
# Out:
# 1
# 1
# [(664,)]
# [('ILSVRC2012_val_00026247.JPEG',)]

# %%
# remove not_correct_list_name from /home/zeyuan.yin/My-Adv/data/images

dir_path = '/home/zeyuan.yin/My-Adv/data/images/'

for name in not_correct_list_name:
    os.system('rm ' + dir_path + name[0])

# check
print(len(os.listdir(dir_path)))
# Out:
# 1000

# %%
# add_filename = ['ILSVRC2012_val_00006011.JPEG','ILSVRC2012_val_00001469.JPEG','ILSVRC2012_val_00003459.JPEG','ILSVRC2012_val_00004136.JPEG','ILSVRC2012_val_00003337.JPEG','ILSVRC2012_val_00003307.JPEG','ILSVRC2012_val_00016088.JPEG','ILSVRC2012_val_00005446.JPEG','ILSVRC2012_val_00017128.JPEG','ILSVRC2012_val_00010965.JPEG']

# add_filename = ['ILSVRC2012_val_00026247.JPEG']

add_filename = ['ILSVRC2012_val_00035146.JPEG']


os.makedirs(dir_path, exist_ok=True)

for name in add_filename:
    os.system('cp /l/users/zeyuan.yin/raw_val/' + name + ' '+ dir_path + name)

# check the number of images in data/
print(len(os.listdir(dir_path)))
# Out:
# 1001
